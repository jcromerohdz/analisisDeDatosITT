# %%
import pandas as pd

# %%
pd.read_csv('iris.csv')
# Out:
#       sl   sw   pl   pw           clase
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 11   4.8  3.4  1.6  0.2     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# 18   5.7  3.8  1.7  0.3     Iris-setosa
# 19   5.1  3.8  1.5  0.3     Iris-setosa
# 20   5.4  3.4  1.7  0.2     Iris-setosa
# 21   5.1  3.7  1.5  0.4     Iris-setosa
# ...

# %%
df=pd.read_csv('iris.csv')

# %%
df.sw
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
# 5      3.9
# 6      3.4
# 7      3.4
# 8      2.9
# 9      3.1
# 10     3.7
# 11     3.4
# 12     3.0
# 13     3.0
# 14     4.0
# 15     4.4
# 16     3.9
# 17     3.5
# 18     3.8
# 19     3.8
# 20     3.4
# 21     3.7
# 22     3.6
# 23     3.3
# 24     3.4
# 25     3.0
# 26     3.4
# 27     3.5
# 28     3.4
# 29     3.2
#       ...
# 120    3.2
# 121    2.8
# 122    2.8
# 123    2.7
# 124    3.3
# 125    3.2
# 126    2.8
# 127    3.0
# 128    2.8
# 129    3.0
# 130    2.8
# 131    3.8
# 132    2.8
# 133    2.8
# 134    2.6
# 135    3.0
# 136    3.4
# 137    3.1
# 138    3.0
# 139    3.1
# 140    3.1
# 141    3.1
# 142    2.7
# 143    3.2
# 144    3.3
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sw, Length: 150, dtype: float64

# %%
df['sl']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
# 5      5.4
# 6      4.6
# 7      5.0
# 8      4.4
# 9      4.9
# 10     5.4
# 11     4.8
# 12     4.8
# 13     4.3
# 14     5.8
# 15     5.7
# 16     5.4
# 17     5.1
# 18     5.7
# 19     5.1
# 20     5.4
# 21     5.1
# 22     4.6
# 23     5.1
# 24     4.8
# 25     5.0
# 26     5.0
# 27     5.2
# 28     5.2
# 29     4.7
#       ...
# 120    6.9
# 121    5.6
# 122    7.7
# 123    6.3
# 124    6.7
# 125    7.2
# 126    6.2
# 127    6.1
# 128    6.4
# 129    7.2
# 130    7.4
# 131    7.9
# 132    6.4
# 133    6.3
# 134    6.1
# 135    7.7
# 136    6.3
# 137    6.4
# 138    6.0
# 139    6.9
# 140    6.7
# 141    6.9
# 142    5.8
# 143    6.8
# 144    6.7
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sl, Length: 150, dtype: float64

# %%
df[['sl','sw']]
# Out:
#       sl   sw
# 0    5.1  3.5
# 1    4.9  3.0
# 2    4.7  3.2
# 3    4.6  3.1
# 4    5.0  3.6
# 5    5.4  3.9
# 6    4.6  3.4
# 7    5.0  3.4
# 8    4.4  2.9
# 9    4.9  3.1
# 10   5.4  3.7
# 11   4.8  3.4
# 12   4.8  3.0
# 13   4.3  3.0
# 14   5.8  4.0
# 15   5.7  4.4
# 16   5.4  3.9
# 17   5.1  3.5
# 18   5.7  3.8
# 19   5.1  3.8
# 20   5.4  3.4
# 21   5.1  3.7
# 22   4.6  3.6
# 23   5.1  3.3
# 24   4.8  3.4
# 25   5.0  3.0
# 26   5.0  3.4
# 27   5.2  3.5
# 28   5.2  3.4
# 29   4.7  3.2
# ..   ...  ...
# 120  6.9  3.2
# 121  5.6  2.8
# 122  7.7  2.8
# 123  6.3  2.7
# 124  6.7  3.3
# 125  7.2  3.2
# 126  6.2  2.8
# 127  6.1  3.0
# 128  6.4  2.8
# 129  7.2  3.0
# 130  7.4  2.8
# 131  7.9  3.8
# 132  6.4  2.8
# 133  6.3  2.8
# 134  6.1  2.6
# 135  7.7  3.0
# 136  6.3  3.4
# 137  6.4  3.1
# 138  6.0  3.0
# 139  6.9  3.1
# 140  6.7  3.1
# 141  6.9  3.1
# 142  5.8  2.7
# 143  6.8  3.2
# 144  6.7  3.3
# 145  6.7  3.0
# 146  6.3  2.5
# 147  6.5  3.0
# 148  6.2  3.4
# 149  5.9  3.0
#
# ...

# %%
df.describe()
# Out:
#                sl          sw          pl          pw
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df_setosa=df[df['clase']=='Iris-setosa']

# %%
df_setosa
# Out:
#      sl   sw   pl   pw        clase
# 0   5.1  3.5  1.4  0.2  Iris-setosa
# 1   4.9  3.0  1.4  0.2  Iris-setosa
# 2   4.7  3.2  1.3  0.2  Iris-setosa
# 3   4.6  3.1  1.5  0.2  Iris-setosa
# 4   5.0  3.6  1.4  0.2  Iris-setosa
# 5   5.4  3.9  1.7  0.4  Iris-setosa
# 6   4.6  3.4  1.4  0.3  Iris-setosa
# 7   5.0  3.4  1.5  0.2  Iris-setosa
# 8   4.4  2.9  1.4  0.2  Iris-setosa
# 9   4.9  3.1  1.5  0.1  Iris-setosa
# 10  5.4  3.7  1.5  0.2  Iris-setosa
# 11  4.8  3.4  1.6  0.2  Iris-setosa
# 12  4.8  3.0  1.4  0.1  Iris-setosa
# 13  4.3  3.0  1.1  0.1  Iris-setosa
# 14  5.8  4.0  1.2  0.2  Iris-setosa
# 15  5.7  4.4  1.5  0.4  Iris-setosa
# 16  5.4  3.9  1.3  0.4  Iris-setosa
# 17  5.1  3.5  1.4  0.3  Iris-setosa
# 18  5.7  3.8  1.7  0.3  Iris-setosa
# 19  5.1  3.8  1.5  0.3  Iris-setosa
# 20  5.4  3.4  1.7  0.2  Iris-setosa
# 21  5.1  3.7  1.5  0.4  Iris-setosa
# 22  4.6  3.6  1.0  0.2  Iris-setosa
# 23  5.1  3.3  1.7  0.5  Iris-setosa
# 24  4.8  3.4  1.9  0.2  Iris-setosa
# ...

# %%
df_setosa[:25]
# Out:
#      sl   sw   pl   pw        clase
# 0   5.1  3.5  1.4  0.2  Iris-setosa
# 1   4.9  3.0  1.4  0.2  Iris-setosa
# 2   4.7  3.2  1.3  0.2  Iris-setosa
# 3   4.6  3.1  1.5  0.2  Iris-setosa
# 4   5.0  3.6  1.4  0.2  Iris-setosa
# 5   5.4  3.9  1.7  0.4  Iris-setosa
# 6   4.6  3.4  1.4  0.3  Iris-setosa
# 7   5.0  3.4  1.5  0.2  Iris-setosa
# 8   4.4  2.9  1.4  0.2  Iris-setosa
# 9   4.9  3.1  1.5  0.1  Iris-setosa
# 10  5.4  3.7  1.5  0.2  Iris-setosa
# 11  4.8  3.4  1.6  0.2  Iris-setosa
# 12  4.8  3.0  1.4  0.1  Iris-setosa
# 13  4.3  3.0  1.1  0.1  Iris-setosa
# 14  5.8  4.0  1.2  0.2  Iris-setosa
# 15  5.7  4.4  1.5  0.4  Iris-setosa
# 16  5.4  3.9  1.3  0.4  Iris-setosa
# 17  5.1  3.5  1.4  0.3  Iris-setosa
# 18  5.7  3.8  1.7  0.3  Iris-setosa
# 19  5.1  3.8  1.5  0.3  Iris-setosa
# 20  5.4  3.4  1.7  0.2  Iris-setosa
# 21  5.1  3.7  1.5  0.4  Iris-setosa
# 22  4.6  3.6  1.0  0.2  Iris-setosa
# 23  5.1  3.3  1.7  0.5  Iris-setosa
# 24  4.8  3.4  1.9  0.2  Iris-setosa

# %%
df_setosa_train=df_setosa[:25]

# %%
df_setosa_test=df_setosa[-25:]

# %%
df_setosa[-25:]
# Out:
#      sl   sw   pl   pw        clase
# 25  5.0  3.0  1.6  0.2  Iris-setosa
# 26  5.0  3.4  1.6  0.4  Iris-setosa
# 27  5.2  3.5  1.5  0.2  Iris-setosa
# 28  5.2  3.4  1.4  0.2  Iris-setosa
# 29  4.7  3.2  1.6  0.2  Iris-setosa
# 30  4.8  3.1  1.6  0.2  Iris-setosa
# 31  5.4  3.4  1.5  0.4  Iris-setosa
# 32  5.2  4.1  1.5  0.1  Iris-setosa
# 33  5.5  4.2  1.4  0.2  Iris-setosa
# 34  4.9  3.1  1.5  0.1  Iris-setosa
# 35  5.0  3.2  1.2  0.2  Iris-setosa
# 36  5.5  3.5  1.3  0.2  Iris-setosa
# 37  4.9  3.1  1.5  0.1  Iris-setosa
# 38  4.4  3.0  1.3  0.2  Iris-setosa
# 39  5.1  3.4  1.5  0.2  Iris-setosa
# 40  5.0  3.5  1.3  0.3  Iris-setosa
# 41  4.5  2.3  1.3  0.3  Iris-setosa
# 42  4.4  3.2  1.3  0.2  Iris-setosa
# 43  5.0  3.5  1.6  0.6  Iris-setosa
# 44  5.1  3.8  1.9  0.4  Iris-setosa
# 45  4.8  3.0  1.4  0.3  Iris-setosa
# 46  5.1  3.8  1.6  0.2  Iris-setosa
# 47  4.6  3.2  1.4  0.2  Iris-setosa
# 48  5.3  3.7  1.5  0.2  Iris-setosa
# 49  5.0  3.3  1.4  0.2  Iris-setosa

# %%
df_versicolor=df[df['clase']=='Iris-versicolor']

# %%
df_versicolor_train=df_versicolor[:25]

# %%
df_versicolor_test=df_versicolor[-25:]

# %%
df_virginica=df[df['clase']=='Iris-virginica']

# %%
df_virginica_train=df_virginica[:25]

# %%
df_virginica_test=df_virginica[-25:]

# %%
len(df_versicolor)
# Out:
# 50

# %%
len(df_setosa)
# Out:
# 50

# %%
len(df_virginica)
# Out:
# 50

# %%
setosa=df_setosa_test[['sl','sw','pl','pw']]

# %%
setosa.xs(25)
# Out:
# sl    5.0
# sw    3.0
# pl    1.6
# pw    0.2
# Name: 25, dtype: float64

# %%
vectori=setosa.xs(25)

# %%
vectori
# Out:
# sl    5.0
# sw    3.0
# pl    1.6
# pw    0.2
# Name: 25, dtype: float64

# %%
setosa.xs(25)-setosa.xs(26)
# Out:
# sl    0.0
# sw   -0.4
# pl    0.0
# pw   -0.2
# dtype: float64

# %%
sum(setosa.xs(25)-setosa.xs(26))
# Out:
# -0.59999999999999987

# %%
pow(sum(setosa.xs(25)-setosa.xs(26)),2)
# Out:
# 0.35999999999999982

# %%
lista_distancia=[]

# %%
lista_distancia.append(pow(sum(setosa.xs(25)-setosa.xs(26)),2))

# %%
lista_distancia
# Out:
# [0.35999999999999982]

# %%
lista_distancia.append(pow(sum(setosa.xs(25)-setosa.xs(27)),2))

# %%
lista_distancia.append(pow(sum(setosa.xs(25)-setosa.xs(28)),2))

# %%
lista_distancia
# Out:
# [0.35999999999999982, 0.3600000000000001, 0.15999999999999992]

# %%
lista_distancia.sort()

# %%
lista_distancia
# Out:
# [0.15999999999999992, 0.35999999999999982, 0.3600000000000001]

# %%
print 'k mas cercano es:', lista_distancia[0]
# Out:
#  k mas cercano es: 0.16

# %%
for i in setosa.values:
    print i
# Out:
# [ 5.   3.   1.6  0.2]
# [ 5.   3.4  1.6  0.4]
# [ 5.2  3.5  1.5  0.2]
# [ 5.2  3.4  1.4  0.2]
# [ 4.7  3.2  1.6  0.2]
# [ 4.8  3.1  1.6  0.2]
# [ 5.4  3.4  1.5  0.4]
# [ 5.2  4.1  1.5  0.1]
# [ 5.5  4.2  1.4  0.2]
# [ 4.9  3.1  1.5  0.1]
# [ 5.   3.2  1.2  0.2]
# [ 5.5  3.5  1.3  0.2]
# [ 4.9  3.1  1.5  0.1]
# [ 4.4  3.   1.3  0.2]
# [ 5.1  3.4  1.5  0.2]
# [ 5.   3.5  1.3  0.3]
# [ 4.5  2.3  1.3  0.3]
# [ 4.4  3.2  1.3  0.2]
# [ 5.   3.5  1.6  0.6]
# [ 5.1  3.8  1.9  0.4]
# [ 4.8  3.   1.4  0.3]
# [ 5.1  3.8  1.6  0.2]
# [ 4.6  3.2  1.4  0.2]
# [ 5.3  3.7  1.5  0.2]
# [ 5.   3.3  1.4  0.2]

# %%
result=[]

# %%
for i in setosa.values:
    result.append(pow(sum(setosa.xs(25)-i),2))

# %%
result.sort()

# %%
result
# Out:
# [0.0,
#  0.0099999999999999291,
#  0.0099999999999999291,
#  0.010000000000000018,
#  0.039999999999999862,
#  0.039999999999999862,
#  0.03999999999999998,
#  0.089999999999999955,
#  0.090000000000000233,
#  0.15999999999999959,
#  0.15999999999999992,
#  0.16000000000000028,
#  0.35999999999999982,
#  0.3600000000000001,
#  0.48999999999999932,
#  0.48999999999999994,
#  0.80999999999999905,
#  0.80999999999999939,
#  0.80999999999999983,
#  0.80999999999999983,
#  0.81000000000000028,
#  1.2099999999999993,
#  1.959999999999998,
#  1.9600000000000011,
#  2.25]

# %%
versicolor=df_versicolor_test[['sl','sw','pl','pw']]

# %%
result2=[]

# %%
versicolor.xs(25)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-8c72f1932f28> in <module>()
# ----> 1 versicolor.xs(25)
#
# /home/itt/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in xs(self, key, axis, level, drop_level)
#    1919                                                       drop_level=drop_level)
#    1920         else:
# -> 1921             loc = self.index.get_loc(key)
#    1922
#    1923             if isinstance(loc, np.ndarray):
#
# /home/itt/anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# ...

# %%
for i in versicolor.values:
    print i
# Out:
# [ 6.6  3.   4.4  1.4]
# [ 6.8  2.8  4.8  1.4]
# [ 6.7  3.   5.   1.7]
# [ 6.   2.9  4.5  1.5]
# [ 5.7  2.6  3.5  1. ]
# [ 5.5  2.4  3.8  1.1]
# [ 5.5  2.4  3.7  1. ]
# [ 5.8  2.7  3.9  1.2]
# [ 6.   2.7  5.1  1.6]
# [ 5.4  3.   4.5  1.5]
# [ 6.   3.4  4.5  1.6]
# [ 6.7  3.1  4.7  1.5]
# [ 6.3  2.3  4.4  1.3]
# [ 5.6  3.   4.1  1.3]
# [ 5.5  2.5  4.   1.3]
# [ 5.5  2.6  4.4  1.2]
# [ 6.1  3.   4.6  1.4]
# [ 5.8  2.6  4.   1.2]
# [ 5.   2.3  3.3  1. ]
# [ 5.6  2.7  4.2  1.3]
# [ 5.7  3.   4.2  1.2]
# [ 5.7  2.9  4.2  1.3]
# [ 6.2  2.9  4.3  1.3]
# [ 5.1  2.5  3.   1.1]
# [ 5.7  2.8  4.1  1.3]

# %%
for i in versicolor.values:
    result2.append(pow(sum(versicolor.xs(25)-i),2))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-94-b3e8859afe93> in <module>()
#       1 for i in versicolor.values:
# ----> 2     result2.append(pow(sum(versicolor.xs(25)-i),2))
#
# /home/itt/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in xs(self, key, axis, level, drop_level)
#    1919                                                       drop_level=drop_level)
#    1920         else:
# -> 1921             loc = self.index.get_loc(key)
#    1922
#    1923             if isinstance(loc, np.ndarray):
#
# /home/itt/anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
# ...

# %%
result2=[]
setosa_train=df_setosa_train[['sl','sw','pl','pw']]

# %%
for i in setosa_train.values:
     result2.append(pow(sum(setosa.xs(25)-i),2))

# %%
result2
# Out:
# [0.15999999999999959,
#  0.0899999999999999,
#  0.15999999999999975,
#  0.16000000000000028,
#  0.15999999999999992,
#  2.5600000000000005,
#  0.010000000000000129,
#  0.0899999999999999,
#  0.80999999999999983,
#  0.039999999999999862,
#  1.0000000000000009,
#  0.039999999999999897,
#  0.25000000000000033,
#  1.6900000000000006,
#  1.9599999999999991,
#  4.8400000000000025,
#  1.4400000000000004,
#  0.24999999999999944,
#  2.8899999999999992,
#  0.80999999999999883,
#  0.81000000000000028,
#  0.80999999999999939,
#  0.16000000000000028,
#  0.63999999999999901,
#  0.24999999999999956]

# %%
result2.sort()

# %%
result2
# Out:
# [0.010000000000000129,
#  0.039999999999999862,
#  0.039999999999999897,
#  0.0899999999999999,
#  0.0899999999999999,
#  0.15999999999999959,
#  0.15999999999999975,
#  0.15999999999999992,
#  0.16000000000000028,
#  0.16000000000000028,
#  0.24999999999999944,
#  0.24999999999999956,
#  0.25000000000000033,
#  0.63999999999999901,
#  0.80999999999999883,
#  0.80999999999999939,
#  0.80999999999999983,
#  0.81000000000000028,
#  1.0000000000000009,
#  1.4400000000000004,
#  1.6900000000000006,
#  1.9599999999999991,
#  2.5600000000000005,
#  2.8899999999999992,
#  4.8400000000000025]

# %%
df_full=pd.concat([df_setosa_train, df_versicolor_train, df_virginica_train])

# %%
df_full_numeric= df_full[['sl','sw','pl','pw']]

# %%
index=df_full_numeric.index

# %%
index[7]
# Out:
# 7

# %%
result=[]
setosa_test=df_setosa_test[['sl','sw','pl','pw']]

# %%
for j,i in enumerate(df_full_numeric.values):
    d=pow(sum(setosa_test.xs(25)-i),2)
    tupla= (d, index[j])
    result.append(tupla)

# %%
result.sort()

# %%
result
# Out:
# [(0.010000000000000129, 6),
#  (0.039999999999999862, 9),
#  (0.039999999999999897, 11),
#  (0.0899999999999999, 1),
#  (0.0899999999999999, 7),
#  (0.15999999999999959, 0),
#  (0.15999999999999975, 2),
#  (0.15999999999999992, 4),
#  (0.16000000000000028, 3),
#  (0.16000000000000028, 22),
#  (0.24999999999999944, 17),
#  (0.24999999999999956, 24),
#  (0.25000000000000033, 12),
#  (0.63999999999999901, 23),
#  (0.80999999999999883, 19),
#  (0.80999999999999939, 21),
#  (0.80999999999999983, 8),
#  (0.81000000000000028, 20),
#  (1.0000000000000009, 10),
#  (1.4400000000000004, 16),
#  (1.6900000000000006, 13),
#  (1.9599999999999991, 14),
#  (2.5600000000000005, 5),
#  (2.8899999999999992, 18),
#  (2.8899999999999997, 60),
#  (3.2400000000000002, 57),
#  (4.8400000000000025, 15),
#  (10.889999999999999, 53),
#  (10.889999999999999, 69),
#  (11.560000000000002, 59),
#  (11.560000000000002, 62),
#  (12.959999999999997, 64),
#  (14.44, 67),
#  (14.440000000000001, 106),
# ...

# %%
df_full.xs(result[0][1])
# Out:
# sl               4.6
# sw               3.4
# pl               1.4
# pw               0.3
# clase    Iris-setosa
# Name: 6, dtype: object

# %%
df_full.xs(result[1][1])
# Out:
# sl               4.9
# sw               3.1
# pl               1.5
# pw               0.1
# clase    Iris-setosa
# Name: 9, dtype: object

# %%
result[0][1]
# Out:
# 6

# %%
result[2][1]
# Out:
# 11

# %%
df_full.xs(result[3][1])
# Out:
# sl               4.9
# sw                 3
# pl               1.4
# pw               0.2
# clase    Iris-setosa
# Name: 1, dtype: object

# %%
for i in result:
    print df_full.xs(i[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-150-4716d0a2f004> in <module>()
#       1 for i in result:
# ----> 2     print df_full.xs(i[0])
#       3
#
# /home/itt/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in xs(self, key, axis, level, drop_level)
#    1919                                                       drop_level=drop_level)
#    1920         else:
# -> 1921             loc = self.index.get_loc(key)
#    1922
#    1923             if isinstance(loc, np.ndarray):
#
# /home/itt/anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
# ...

# %%
len(result)
# Out:
# 75

# %%
print df_full.xs(result[0][1])
# Out:
# sl               4.6
# sw               3.4
# pl               1.4
# pw               0.3
# clase    Iris-setosa
# Name: 6, dtype: object
