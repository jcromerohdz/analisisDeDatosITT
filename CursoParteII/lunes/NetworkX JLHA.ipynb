# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph()
G.add_node(11)
G.add_nodes_from([22,33])
H = nx.path_graph(10)
nx.draw(H,with_labels=True)
# Out:
# /home/itt/anaconda2/lib/python2.7/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /home/itt/anaconda2/lib/python2.7/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /home/itt/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /home/itt/anaconda2/lib/python2.7/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
# ...

# %%
G.nodes()
# Out:
# [33, 11, 22]

# %%
g = nx.karate_club_graph()

# %%
nx.draw(g,with_labels = True)
lista = g.degree()

# %%
plt.show()

# %%
print lista
# Out:
# {0: 16, 1: 9, 2: 10, 3: 6, 4: 3, 5: 4, 6: 4, 7: 4, 8: 5, 9: 2, 10: 3, 11: 1, 12: 2, 13: 5, 14: 2, 15: 2, 16: 2, 17: 2, 18: 2, 19: 3, 20: 2, 21: 2, 22: 2, 23: 5, 24: 3, 25: 3, 26: 2, 27: 4, 28: 3, 29: 4, 30: 4, 31: 6, 32: 12, 33: 17}

# %%
import numpy as np
histograma = nx.degree_histogram(g)
print histograma
# Out:
# [0, 1, 11, 6, 6, 3, 2, 0, 0, 1, 1, 0, 1, 0, 0, 0, 1, 1]

# %%
num_nodos = nx.number_of_nodes(g)
print num_nodos
distribucion_grado = np.array(histograma)/float(num_nodos)
# Out:
# 34

# %%
plt.hist(histograma)
plt.show()

# %%
G.add_nodes_from(H)

# %%
G.nodes()
# Out:
# [0, 33, 2, 3, 4, 5, 6, 1, 8, 9, 11, 22, 7]

# %%
G.add_edge(33,44)
G.nodes()
# Out:
# [0, 33, 2, 3, 4, 5, 6, 1, 8, 9, 11, 44, 22, 7]

# %%
G.add_edge(10,2)
G.add_edge(4,11)
nx.draw(G,with_labels = True)

# %%
plt.show()

# %%
agrupacion = nx.clustering(g)
print agrupacion
# Out:
# {0: 0.15, 1: 0.3333333333333333, 2: 0.24444444444444444, 3: 0.6666666666666666, 4: 0.6666666666666666, 5: 0.5, 6: 0.5, 7: 1.0, 8: 0.5, 9: 0.0, 10: 0.6666666666666666, 11: 0.0, 12: 1.0, 13: 0.6, 14: 1.0, 15: 1.0, 16: 1.0, 17: 1.0, 18: 1.0, 19: 0.3333333333333333, 20: 1.0, 21: 1.0, 22: 1.0, 23: 0.4, 24: 0.3333333333333333, 25: 0.3333333333333333, 26: 1.0, 27: 0.16666666666666666, 28: 0.3333333333333333, 29: 0.6666666666666666, 30: 0.5, 31: 0.2, 32: 0.19696969696969696, 33: 0.09803921568627451, 44: 0.0}

# %%
path = nx.shortest_path(g, 16, 25)
caminos = nx.all_shortest_paths(g, 16,25)
longitud = nx.shortest_path_length(g, 16, 25)
print path
print( [p for p in caminos] )
print longitud
# Out:
# [16, 5, 0, 31, 25]
# [[16, 5, 0, 31, 25], [16, 6, 0, 31, 25]]
# 4

# %%
distancia = nx.dijkstra_path(g, 16, 25)
print distancia
print nx.dijkstra_path_length(g, 16, 25)
print nx.floyd_warshall(g)
# Out:
# [16, 5, 0, 31, 25]
# 4
# ...

# %%
print nx.betweenness_centrality(g)
# Out:
# {0: 0.42655971479500904, 1: 0.052673796791443836, 2: 0.13597034773505362, 3: 0.011692555810202869, 4: 0.0005941770647653, 5: 0.029114676173499707, 6: 0.0291146761734997, 7: 0.0, 8: 0.05717398070339247, 9: 0.0012223071046600458, 10: 0.0005941770647653, 11: 0.0, 12: 0.0, 13: 0.051199671787907075, 14: 0.0, 15: 0.0, 16: 0.0, 17: 0.0, 18: 0.0, 19: 0.03590810061398297, 20: 0.0, 21: 0.0, 22: 0.0, 23: 0.01746880570409982, 24: 0.00207961972667855, 25: 0.0036145771439889084, 26: 0.0, 27: 0.022335398805987037, 28: 0.002113572701807996, 29: 0.002750190985485103, 30: 0.014795008912655965, 31: 0.1360368389780154, 32: 0.13712757830404887, 33: 0.34501174207056556, 44: 0.0}
