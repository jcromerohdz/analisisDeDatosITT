# %%
#copiar a /home/itt/anaconda2/bin el archivo
import pandas as pd
df = pd.read_csv('iris.data.csv')

# %%
df
# Out:
#       sl   sw   pl   pw           clase
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 11   4.8  3.4  1.6  0.2     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# 18   5.7  3.8  1.7  0.3     Iris-setosa
# 19   5.1  3.8  1.5  0.3     Iris-setosa
# 20   5.4  3.4  1.7  0.2     Iris-setosa
# 21   5.1  3.7  1.5  0.4     Iris-setosa
# ...

# %%
df[['sl','sw']] #accede a la columna
# Out:
#       sl   sw
# 0    5.1  3.5
# 1    4.9  3.0
# 2    4.7  3.2
# 3    4.6  3.1
# 4    5.0  3.6
# 5    5.4  3.9
# 6    4.6  3.4
# 7    5.0  3.4
# 8    4.4  2.9
# 9    4.9  3.1
# 10   5.4  3.7
# 11   4.8  3.4
# 12   4.8  3.0
# 13   4.3  3.0
# 14   5.8  4.0
# 15   5.7  4.4
# 16   5.4  3.9
# 17   5.1  3.5
# 18   5.7  3.8
# 19   5.1  3.8
# 20   5.4  3.4
# 21   5.1  3.7
# 22   4.6  3.6
# 23   5.1  3.3
# 24   4.8  3.4
# 25   5.0  3.0
# 26   5.0  3.4
# 27   5.2  3.5
# 28   5.2  3.4
# 29   4.7  3.2
# ..   ...  ...
# 120  6.9  3.2
# 121  5.6  2.8
# 122  7.7  2.8
# 123  6.3  2.7
# 124  6.7  3.3
# 125  7.2  3.2
# 126  6.2  2.8
# 127  6.1  3.0
# 128  6.4  2.8
# 129  7.2  3.0
# 130  7.4  2.8
# 131  7.9  3.8
# 132  6.4  2.8
# 133  6.3  2.8
# 134  6.1  2.6
# 135  7.7  3.0
# 136  6.3  3.4
# 137  6.4  3.1
# 138  6.0  3.0
# 139  6.9  3.1
# 140  6.7  3.1
# 141  6.9  3.1
# 142  5.8  2.7
# 143  6.8  3.2
# 144  6.7  3.3
# 145  6.7  3.0
# 146  6.3  2.5
# 147  6.5  3.0
# 148  6.2  3.4
# 149  5.9  3.0
#
# ...

# %%
df['sl']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
# 5      5.4
# 6      4.6
# 7      5.0
# 8      4.4
# 9      4.9
# 10     5.4
# 11     4.8
# 12     4.8
# 13     4.3
# 14     5.8
# 15     5.7
# 16     5.4
# 17     5.1
# 18     5.7
# 19     5.1
# 20     5.4
# 21     5.1
# 22     4.6
# 23     5.1
# 24     4.8
# 25     5.0
# 26     5.0
# 27     5.2
# 28     5.2
# 29     4.7
#       ...
# 120    6.9
# 121    5.6
# 122    7.7
# 123    6.3
# 124    6.7
# 125    7.2
# 126    6.2
# 127    6.1
# 128    6.4
# 129    7.2
# 130    7.4
# 131    7.9
# 132    6.4
# 133    6.3
# 134    6.1
# 135    7.7
# 136    6.3
# 137    6.4
# 138    6.0
# 139    6.9
# 140    6.7
# 141    6.9
# 142    5.8
# 143    6.8
# 144    6.7
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sl, Length: 150, dtype: float64

# %%
df.sl
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
# 5      5.4
# 6      4.6
# 7      5.0
# 8      4.4
# 9      4.9
# 10     5.4
# 11     4.8
# 12     4.8
# 13     4.3
# 14     5.8
# 15     5.7
# 16     5.4
# 17     5.1
# 18     5.7
# 19     5.1
# 20     5.4
# 21     5.1
# 22     4.6
# 23     5.1
# 24     4.8
# 25     5.0
# 26     5.0
# 27     5.2
# 28     5.2
# 29     4.7
#       ...
# 120    6.9
# 121    5.6
# 122    7.7
# 123    6.3
# 124    6.7
# 125    7.2
# 126    6.2
# 127    6.1
# 128    6.4
# 129    7.2
# 130    7.4
# 131    7.9
# 132    6.4
# 133    6.3
# 134    6.1
# 135    7.7
# 136    6.3
# 137    6.4
# 138    6.0
# 139    6.9
# 140    6.7
# 141    6.9
# 142    5.8
# 143    6.8
# 144    6.7
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sl, Length: 150, dtype: float64

# %%
#Muestra la clase Iris-setosa
df_setosa = df[df['clase']=='Iris-setosa']
df_setosa
# Out:
#      sl   sw   pl   pw        clase
# 0   5.1  3.5  1.4  0.2  Iris-setosa
# 1   4.9  3.0  1.4  0.2  Iris-setosa
# 2   4.7  3.2  1.3  0.2  Iris-setosa
# 3   4.6  3.1  1.5  0.2  Iris-setosa
# 4   5.0  3.6  1.4  0.2  Iris-setosa
# 5   5.4  3.9  1.7  0.4  Iris-setosa
# 6   4.6  3.4  1.4  0.3  Iris-setosa
# 7   5.0  3.4  1.5  0.2  Iris-setosa
# 8   4.4  2.9  1.4  0.2  Iris-setosa
# 9   4.9  3.1  1.5  0.1  Iris-setosa
# 10  5.4  3.7  1.5  0.2  Iris-setosa
# 11  4.8  3.4  1.6  0.2  Iris-setosa
# 12  4.8  3.0  1.4  0.1  Iris-setosa
# 13  4.3  3.0  1.1  0.1  Iris-setosa
# 14  5.8  4.0  1.2  0.2  Iris-setosa
# 15  5.7  4.4  1.5  0.4  Iris-setosa
# 16  5.4  3.9  1.3  0.4  Iris-setosa
# 17  5.1  3.5  1.4  0.3  Iris-setosa
# 18  5.7  3.8  1.7  0.3  Iris-setosa
# 19  5.1  3.8  1.5  0.3  Iris-setosa
# 20  5.4  3.4  1.7  0.2  Iris-setosa
# 21  5.1  3.7  1.5  0.4  Iris-setosa
# 22  4.6  3.6  1.0  0.2  Iris-setosa
# 23  5.1  3.3  1.7  0.5  Iris-setosa
# 24  4.8  3.4  1.9  0.2  Iris-setosa
# ...

# %%
df
# Out:
#       sl   sw   pl   pw           clase
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 11   4.8  3.4  1.6  0.2     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# 18   5.7  3.8  1.7  0.3     Iris-setosa
# 19   5.1  3.8  1.5  0.3     Iris-setosa
# 20   5.4  3.4  1.7  0.2     Iris-setosa
# 21   5.1  3.7  1.5  0.4     Iris-setosa
# ...

# %%
df_setosa_train=df_setosa[:25] #Toma los primeros 25 para entrenamiento

# %%
f_setosa_train=df_setosa[0:25]

# %%
f_setosa_test=df_setosa[-25:]
f_setosa_test
# Out:
#      sl   sw   pl   pw        clase
# 25  5.0  3.0  1.6  0.2  Iris-setosa
# 26  5.0  3.4  1.6  0.4  Iris-setosa
# 27  5.2  3.5  1.5  0.2  Iris-setosa
# 28  5.2  3.4  1.4  0.2  Iris-setosa
# 29  4.7  3.2  1.6  0.2  Iris-setosa
# 30  4.8  3.1  1.6  0.2  Iris-setosa
# 31  5.4  3.4  1.5  0.4  Iris-setosa
# 32  5.2  4.1  1.5  0.1  Iris-setosa
# 33  5.5  4.2  1.4  0.2  Iris-setosa
# 34  4.9  3.1  1.5  0.1  Iris-setosa
# 35  5.0  3.2  1.2  0.2  Iris-setosa
# 36  5.5  3.5  1.3  0.2  Iris-setosa
# 37  4.9  3.1  1.5  0.1  Iris-setosa
# 38  4.4  3.0  1.3  0.2  Iris-setosa
# 39  5.1  3.4  1.5  0.2  Iris-setosa
# 40  5.0  3.5  1.3  0.3  Iris-setosa
# 41  4.5  2.3  1.3  0.3  Iris-setosa
# 42  4.4  3.2  1.3  0.2  Iris-setosa
# 43  5.0  3.5  1.6  0.6  Iris-setosa
# 44  5.1  3.8  1.9  0.4  Iris-setosa
# 45  4.8  3.0  1.4  0.3  Iris-setosa
# 46  5.1  3.8  1.6  0.2  Iris-setosa
# 47  4.6  3.2  1.4  0.2  Iris-setosa
# 48  5.3  3.7  1.5  0.2  Iris-setosa
# 49  5.0  3.3  1.4  0.2  Iris-setosa

# %%
#Muestra la clase Iris-setosa
df_setosa = df[df['clase']=='Iris-setosa']
df_versicolor = df[df['clase']=='Iris-versicolor']
df_virginica = df[df['clase']=='Iris-virginica']
largoSetosa=setosa=len(df_setosa) #51
largoVersi= len(df_versicolor)#50
largoVir=len(df_virginica)#49
print largoSetosa
print largoVersi
print largoVir
# Out:
# 50
# 50
# 50

# %%
df_setosa = df[df['clase']=='Iris-setosa']
df_versicolor = df[df['clase']=='Iris-versicolor']
df_virginica = df[df['clase']=='Iris-virginica']
#Selecciona Grupo para entrenamiento y test
f_setosa_test=df_setosa[-25:]
f_setosa_train=df_setosa[0:26]

f_versiTrain= df_versicolor[:25] #Toma los primeros 25 para entrenamiento
f_versiTest= df_versicolor[-25:]

f_virgiTrain=df_virginica[:25] #Toma los primeros 25 para entrenamiento
f_virgiTest= df_virginica[-25:]
#Obtiene solo numericos
setosaTest=f_setosa_test[['sl','sw','pl','pw']]
setosaTrain=f_setosa_test[['sl','sw','pl','pw']]

versiTexs=f_versiTrain[['sl','sw','pl','pw']]
versiTrain=f_setosa_train[['sl','sw','pl','pw']]

virgiTrain=f_virgiTrain[['sl','sw','pl','pw']]
virgiTest= f_virgiTest[['sl','sw','pl','pw']]

resta = virgiTest-virgiTrain

import matplotlib as plt
plt.scatter(df_full_numeric['sl']),.scatter(df_full_numeric['sl']),

# %%
f_virginica
# Out:
#       sl   sw   pl   pw           clase
# 125  7.2  3.2  6.0  1.8  Iris-virginica
# 126  6.2  2.8  4.8  1.8  Iris-virginica
# 127  6.1  3.0  4.9  1.8  Iris-virginica
# 128  6.4  2.8  5.6  2.1  Iris-virginica
# 129  7.2  3.0  5.8  1.6  Iris-virginica
# 130  7.4  2.8  6.1  1.9  Iris-virginica
# 131  7.9  3.8  6.4  2.0  Iris-virginica
# 132  6.4  2.8  5.6  2.2  Iris-virginica
# 133  6.3  2.8  5.1  1.5  Iris-virginica
# 134  6.1  2.6  5.6  1.4  Iris-virginica
# 135  7.7  3.0  6.1  2.3  Iris-virginica
# 136  6.3  3.4  5.6  2.4  Iris-virginica
# 137  6.4  3.1  5.5  1.8  Iris-virginica
# 138  6.0  3.0  4.8  1.8  Iris-virginica
# 139  6.9  3.1  5.4  2.1  Iris-virginica
# 140  6.7  3.1  5.6  2.4  Iris-virginica
# 141  6.9  3.1  5.1  2.3  Iris-virginica
# 142  5.8  2.7  5.1  1.9  Iris-virginica
# 143  6.8  3.2  5.9  2.3  Iris-virginica
# 144  6.7  3.3  5.7  2.5  Iris-virginica
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# ...

# %%
 setosa_test2.xs(25)
# Out:
# sl    5.0
# sw    3.0
# pl    1.6
# pw    0.2
# Name: 25, dtype: float64

# %%
# Out:
#      sl   sw   pl   pw
# 25  5.0  3.0  1.6  0.2
# 26  5.0  3.4  1.6  0.4
# 27  5.2  3.5  1.5  0.2
# 28  5.2  3.4  1.4  0.2
# 29  4.7  3.2  1.6  0.2
# 30  4.8  3.1  1.6  0.2
# 31  5.4  3.4  1.5  0.4
# 32  5.2  4.1  1.5  0.1
# 33  5.5  4.2  1.4  0.2
# 34  4.9  3.1  1.5  0.1
# 35  5.0  3.2  1.2  0.2
# 36  5.5  3.5  1.3  0.2
# 37  4.9  3.1  1.5  0.1
# 38  4.4  3.0  1.3  0.2
# 39  5.1  3.4  1.5  0.2
# 40  5.0  3.5  1.3  0.3
# 41  4.5  2.3  1.3  0.3
# 42  4.4  3.2  1.3  0.2
# 43  5.0  3.5  1.6  0.6
# 44  5.1  3.8  1.9  0.4
# 45  4.8  3.0  1.4  0.3
# 46  5.1  3.8  1.6  0.2
# 47  4.6  3.2  1.4  0.2
# 48  5.3  3.7  1.5  0.2
# 49  5.0  3.3  1.4  0.2

# %%
f_setosa_test
# Out:
#      sl   sw   pl   pw        clase
# 25  5.0  3.0  1.6  0.2  Iris-setosa
# 26  5.0  3.4  1.6  0.4  Iris-setosa
# 27  5.2  3.5  1.5  0.2  Iris-setosa
# 28  5.2  3.4  1.4  0.2  Iris-setosa
# 29  4.7  3.2  1.6  0.2  Iris-setosa
# 30  4.8  3.1  1.6  0.2  Iris-setosa
# 31  5.4  3.4  1.5  0.4  Iris-setosa
# 32  5.2  4.1  1.5  0.1  Iris-setosa
# 33  5.5  4.2  1.4  0.2  Iris-setosa
# 34  4.9  3.1  1.5  0.1  Iris-setosa
# 35  5.0  3.2  1.2  0.2  Iris-setosa
# 36  5.5  3.5  1.3  0.2  Iris-setosa
# 37  4.9  3.1  1.5  0.1  Iris-setosa
# 38  4.4  3.0  1.3  0.2  Iris-setosa
# 39  5.1  3.4  1.5  0.2  Iris-setosa
# 40  5.0  3.5  1.3  0.3  Iris-setosa
# 41  4.5  2.3  1.3  0.3  Iris-setosa
# 42  4.4  3.2  1.3  0.2  Iris-setosa
# 43  5.0  3.5  1.6  0.6  Iris-setosa
# 44  5.1  3.8  1.9  0.4  Iris-setosa
# 45  4.8  3.0  1.4  0.3  Iris-setosa
# 46  5.1  3.8  1.6  0.2  Iris-setosa
# 47  4.6  3.2  1.4  0.2  Iris-setosa
# 48  5.3  3.7  1.5  0.2  Iris-setosa
# 49  5.0  3.3  1.4  0.2  Iris-setosa

# %%
pow(sum(setosa.xs(25)-setosa.xs(26)),2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-58f450ecf94c> in <module>()
# ----> 1 pow(sum(setosa.xs(25)-setosa.xs(26)),2)
#
# AttributeError: 'int' object has no attribute 'xs'

# %%
df_setosa = df[df['clase']=='Iris-setosa']
df_versicolor = df[df['clase']=='Iris-versicolor']
df_virginica = df[df['clase']=='Iris-virginica']
#Selecciona Grupo para entrenamiento y test
f_setosa_test=df_setosa[-25:]
f_setosa_train=df_setosa[0:26]

f_versiTrain= df_versicolor[:25] #Toma los primeros 25 para entrenamiento
f_versiTest= df_versicolor[-25:]

f_virgiTrain=df_virginica[:25] #Toma los primeros 25 para entrenamiento
f_virgiTest= df_virginica[-25:]
#Obtiene solo numericos
setosaTest=f_setosa_test[['sl','sw','pl','pw']]
setosaTrain=f_setosa_test[['sl','sw','pl','pw']]

versiTexs=f_versiTrain[['sl','sw','pl','pw']]
versiTrain=f_setosa_train[['sl','sw','pl','pw']]

virgiTrain=f_virgiTrain[['sl','sw','pl','pw']]
virgiTest= f_virgiTest[['sl','sw','pl','pw']]

resta = virgiTest-virgiTrain

#import matplotlib as plt
#plt.scatter(df_full_numeric['sl']),.scatter(df_full_numeric['sl']),
lista_distancia = []
lista_distancia.append(pow(sum(setosaTest[5]-setosaTest[7]),2))
for i in setosa.values:
    result = pow(setosa.xs(25)-i)
print result
resulta= []
for i in setosa.values:
    resulta.append(pow(sum(setosa.xs(25)-setosa.xs(28)),2))
result.sort
result2= []
for i in setosa_train.values:
    result2.append(pow(sum(setosa.xs(25)-i),2))
    print result2
#concatenar
#df_full = pd.concat([df_setosa_train, df_versicolor_train, df_virginica])
#df_full_numeric = df_full[['sl','sw','pl','pw']]
#for i in df_full
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-125-1e9c7251d962> in <module>()
#      26 #plt.scatter(df_full_numeric['sl']),.scatter(df_full_numeric['sl']),
#      27 lista_distancia = []
# ---> 28 lista_distancia.append(pow(sum(setosaTest[5]-setosaTest[7]),2))
#      29 for i in setosa.values:
#      30     result = pow(setosa.xs(25)-i)
#
# /home/itt/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /home/itt/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
# ...

# %%
setosaTest['sw']-virgiTest['sl']
# Out:
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# 30    NaN
# 31    NaN
# 32    NaN
# 33    NaN
# 34    NaN
# 35    NaN
# 36    NaN
# 37    NaN
# 38    NaN
# 39    NaN
# 40    NaN
# 41    NaN
# 42    NaN
# 43    NaN
# 44    NaN
# 45    NaN
# 46    NaN
# 47    NaN
# 48    NaN
# 49    NaN
# 125   NaN
# 126   NaN
# 127   NaN
# 128   NaN
# 129   NaN
# 130   NaN
# 131   NaN
# 132   NaN
# 133   NaN
# 134   NaN
# 135   NaN
# 136   NaN
# 137   NaN
# 138   NaN
# 139   NaN
# 140   NaN
# 141   NaN
# 142   NaN
# 143   NaN
# 144   NaN
# 145   NaN
# 146   NaN
# 147   NaN
# 148   NaN
# 149   NaN
# dtype: float64

# %%
df_full = pd.concat([df_setosa_train,versiTrain, df_virginica])
df_full_numeric = df_full[['sl','sw','pl','pw']]
indices =[range(1,149)]
result3 = []
for j, i in enumerate(df_full_numeric.values):
    d= pow(sum(setosaTest.xs(25)-i),2)
    tupla = (d, indices[j])
    result3.append((d, indices[j]))
    result3.sort()    
    #Falta imprimir que clase es    
    result3[0] # Nos muestra el primer elemento de testeo
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-116-906ea1ea7433> in <module>()
#       5 for j, i in enumerate(df_full_numeric.values):
#       6     d= pow(sum(setosaTest.xs(25)-i),2)
# ----> 7     tupla = (d, indices[j])
#       8     result3.append((d, indices[j]))
#       9     result3.sort()
#
# IndexError: list index out of range
