# %%
#copiar a /home/itt/anaconda2/bin el archivo
import pandas as pd
df = pd.read_csv('Bienestar.csv')

# %%
len(df)
# Out:
# 10654

# %%
df
# Out:
#        anio_reg  trimestre      folio  hog_ent_1  hog_ent_2  id_pobla  sexo  \
# 0          2012          1  191204070          1          0         1     1
# 1          2012          1  141201084          1          0         1     1
# 2          2012          1  311204053          1          0         2     2
# 3          2012          1  131206082          1          0         2     2
# 4          2012          1  261206013          1          0         1     1
# 5          2012          1  201203058          1          0         1     1
# 6          2012          1   31203033          3          0         1     1
# 7          2012          1   91201092          1          0         2     2
# 8          2012          1  151201119          1          0         1     1
# 9          2012          1  221204051          1          0         1     1
# 10         2012          1  111203058          1          0         1     1
# ...

# %%
df.to_cvs("misalida2.cvs", index=False) #Exportar
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-449cbcb580c1> in <module>()
# ----> 1 df.to_cvs("misalida2.cvs", index=False) #Exportar
#
# /home/itt/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'to_cvs'
